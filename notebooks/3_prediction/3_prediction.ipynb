# %% [markdown]
# # Programming Data Science Project
# # 3. Prediction
# ## Imports

# %%
import yellowcab

# %%
trip_data = yellowcab.io.read_all_files("parquet")

# %% [markdown]
# Add weather data

# %%
trip_data = yellowcab.io.add_weather_data(trip_data)
# Out:
#         tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0        2020-01-01 00:29:01   2020-01-01 00:40:28              2.0
# 1        2020-01-01 00:50:58   2020-01-01 01:06:09              1.0
# 2        2020-01-01 00:24:18   2020-01-01 00:52:47              1.0
# 3        2020-01-01 00:40:58   2020-01-01 00:51:25              1.0
# 4        2020-01-01 00:47:46   2020-01-01 01:03:04              1.0
# ...                      ...                   ...              ...
# 7376902  2020-02-29 08:10:41   2020-02-29 08:34:28              1.0
# 7376903  2020-07-15 14:59:45   2020-07-15 15:31:18              1.0
# 7376904  2020-02-05 14:15:01   2020-02-05 15:25:56              1.0
# 7376905  2020-09-25 21:32:15   2020-09-25 22:23:35              2.0
# 7376906  2020-03-31 15:02:04   2020-03-31 16:00:28              1.0
#
#          trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# ...

# %% [markdown]
# ## a) Trip distance with new features

# %% [markdown]
# ## b) Fare amount, parsimonious model with start information

# %% [markdown]
# ## c) Payment type

# %% [markdown]
# ## d) Further predictions
