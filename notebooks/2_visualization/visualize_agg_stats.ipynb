# %% [markdown]
# # Visualization

# %% [markdown]
# Task 2c:
# **For each month, visualize the distribution of trip lengths.** ~~Compare the distributions to normal
# distributions with mean and standard deviation as calculated before (1.d))~~

# %%
import yellowcab

# %%
trip_data = yellowcab.io.read_all_files('parquet')

# %%
yellowcab.vis.visualize_trip_lengths(trip_data)
