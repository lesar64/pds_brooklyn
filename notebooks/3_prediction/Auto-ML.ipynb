# %%
from lazypredict.Supervised import LazyRegressor, LazyClassifier
import yellowcab
import pandas as pd
import geopandas as gpd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
trip_data = yellowcab.io.read_all_files('parquet')
trip_data = trip_data[:10000]
trip_data = trip_data.drop(columns=['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'PUBorough', 'PUZone', 'PUService_zone', 'DOBorough'], axis=1)

# %%
st_scaler = StandardScaler()
X_test_scaled = st_scaler.transform(X_test)

# %%
y = trip_data['trip_distance']
X = trip_data.drop(columns=['trip_distance'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

# %%
reg = LazyRegressor(ignore_warnings=False)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
#  21%|████████████████████████▋                                                                                          | 9/42 [00:08<00:46,  1.42s/it]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range for family GammaDistribution
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 42/42 [01:20<00:00,  1.92s/it]

# %%
sns.pairplot(X_train)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3b9c235f66bf> in <module>
#       1 sns.pairplot(X_train)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined
