# %%
# Imports
import yellowcab
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read data
data = yellowcab.io.read_all_files("parquet")

# %% [markdown]
# ### Creating an overview of new Covid-19 Cases

# %%
yellowcab.vis.create_corona_cases_overview()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Julian\\miniconda3\\envs\\PDS21\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### Plot total passengers per calendar week

# %%
yellowcab.vis.create_passenger_overview(data)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Julian\\miniconda3\\envs\\PDS21\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### Plot hourly passengers of week 10 and 13

# %%
yellowcab.vis.week_comparison(data)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Julian\\miniconda3\\envs\\PDS21\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### Plot Total duration in the month march

# %%
yellowcab.vis.create_march_overview(data)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Julian\\miniconda3\\envs\\PDS21\\lib\\site-packages\\matplotlib\\pyplot.py'>
